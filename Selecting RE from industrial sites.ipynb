# %% [markdown]
# # Selecting existng renewable energy sites closer from the industrial sites

# %%
from IPython.display import display, HTML

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd

# %%
# importing renewable point source datasets
file_path = "C:/Users/USER/Desktop/MSc_Data_Science/Ind_Project/GHD/Project/Data/REPD_GB_1.csv"

# Load the CSV file into a DataFrame
repd = pd.read_csv(file_path, encoding='latin1')

# Display DataFrame (repd = renewable energy pointsource data)
repd
# Out:
#       OBJECTID                                          Site Name  \
# 0          337                                  Great Glen Scheme
# 1          338                               Glendoe Hydro Scheme
# 2          340                          Fasnakyle Hydro Extension
# 3          341                   Kinlochleven Hydro Power Station
# 4          342                                               Gaur
# ...        ...                                                ...
# 2346      9760    Biggin Hill Airport, Main Road - Solar PV Array
# 2347      9831  Farnborough International Exhibition Centre, E...
# 2348      9937                        Hare Brewery - Solar Panels
# 2349     10069                    Jones Food Company - Solar Farm
# 2350     10118                           Sutton Bridge Solar Farm
#
#           Technology Type Installed Capacity (MWelec)  Development Status
# 0             Large Hydro                          36         Operational
# 1             Large Hydro                         100         Operational
# 2             Large Hydro                         7.5         Operational
# 3             Large Hydro                        19.5         Operational
# 4             Large Hydro                         6.4         Operational
# ...                   ...                         ...                 ...
# 2346  Solar Photovoltaics                          12  Under Construction
# 2347  Solar Photovoltaics                        1.15  Under Construction
# 2348  Solar Photovoltaics                        0.25         Operational
# 2349  Solar Photovoltaics                        0.71         Operational
# 2350  Solar Photovoltaics                        49.9  Under Construction
#
# [2351 rows x 5 columns]

# %% [markdown]
# # Importing NearTable run on ArcGIS Pro. It shows the nearest three RE locations from each industrial site

# %%
# nt = near table (distance calculated from each industrial site to power substation using ArcGIS Pro 
# 1= nearest, 2= second nearest, 3 = furthest within 3)
# IN_FID = Industrial sites
# NEAR_FID = RE sites
# NEAR_DIST = distance from industrial sites to RE sites

file_path = "C:/Users/USER/Desktop/MSc_Data_Science/Ind_Project/GHD/Project/Data/repd_nearTable.csv"

# Load the CSV file into a DataFrame
repd_nt = pd.read_csv(file_path)     

# Display DataFrame
repd_nt
# Out:
#       IN_FID  NEAR_FID     NEAR_DIST  NEAR_RANK
# 0          1      7296   2137.755833          1
# 1          1      2755   7285.257030          2
# 2          1      1115  10806.566383          3
# 3          2      4739  10593.654138          1
# 4          2      4057  13546.571854          2
# ...      ...       ...           ...        ...
# 3175    1059      1838   3430.695702          2
# 3176    1059      4640   3655.379597          3
# 3177    1060      5198   5394.315990          1
# 3178    1060      1877   6059.947360          2
# 3179    1060      1787   6099.016068          3
#
# [3180 rows x 4 columns]

# %%
# # Drop the OBJECTID from the nt DataFrame
# nt = nt.drop(columns=['Rowid'])
# nt

# %%
# Rename the NEAR_FID column to OBJECTID in the nt DataFrame
# NEAR_FID are OBJECTID of power station's table and IN_FID = OBJECTID of NAEI

repd_nt.rename(columns={'NEAR_FID': 'OBJECTID'}, inplace=True)

repd_nt
# Out:
#       IN_FID  OBJECTID     NEAR_DIST  NEAR_RANK
# 0          1      7296   2137.755833          1
# 1          1      2755   7285.257030          2
# 2          1      1115  10806.566383          3
# 3          2      4739  10593.654138          1
# 4          2      4057  13546.571854          2
# ...      ...       ...           ...        ...
# 3175    1059      1838   3430.695702          2
# 3176    1059      4640   3655.379597          3
# 3177    1060      5198   5394.315990          1
# 3178    1060      1877   6059.947360          2
# 3179    1060      1787   6099.016068          3
#
# [3180 rows x 4 columns]

# %%
# Merge the two DataFrames on the OBJECTID column
merged_df = pd.merge(repd, repd_nt, on='OBJECTID', how='inner')

merged_df
# Out:
#       OBJECTID                                          Site Name  \
# 0          346                                            Striven
# 1          348                                          Kilmorack
# 2          349                                              Orrin
# 3          350                                        Tor Achilty
# 4          361                          Beeston Weir Hydro Scheme
# ...        ...                                                ...
# 3175      9831  Farnborough International Exhibition Centre, E...
# 3176      9831  Farnborough International Exhibition Centre, E...
# 3177      9831  Farnborough International Exhibition Centre, E...
# 3178      9937                        Hare Brewery - Solar Panels
# 3179     10069                    Jones Food Company - Solar Farm
#
#           Technology Type Installed Capacity (MWelec)  Development Status  \
# 0             Large Hydro                           8         Operational
# 1             Large Hydro                          20         Operational
# 2             Large Hydro                          18         Operational
# 3             Large Hydro                          15         Operational
# 4             Small Hydro                         1.7         Operational
# ...                   ...                         ...                 ...
# 3175  Solar Photovoltaics                        1.15  Under Construction
# 3176  Solar Photovoltaics                        1.15  Under Construction
# 3177  Solar Photovoltaics                        1.15  Under Construction
# 3178  Solar Photovoltaics                        0.25         Operational
# 3179  Solar Photovoltaics                        0.71         Operational
#
#       IN_FID     NEAR_DIST  NEAR_RANK
# 0        430  15756.589891          3
# 1        994   6962.379263          2
# 2        994   4877.812009          1
# 3        994   7993.373818          3
# 4        305   3152.935140          2
# ...      ...           ...        ...
# 3175     896  13227.073183          1
# 3176     919   2655.045762          1
# 3177     987   6178.850783          1
# 3178     529   8167.793643          2
# 3179     401   2294.632432          2
#
# [3180 rows x 8 columns]

# %%
merged_df.columns
# Out:
# Index(['OBJECTID', 'Site Name', 'Technology Type',
#        'Installed Capacity (MWelec)', 'Development Status', 'IN_FID',
#        'NEAR_DIST', 'NEAR_RANK'],
#       dtype='object')

# %%
# # Drop the specified columns from the nt DataFrame
# merged_df = merged_df.drop(columns=['PF'])
# merged_df

# %%
# Sort the dataframe by IN_FID and then by NEAR_DIST to ensure proper ordering
sorted_df = merged_df.sort_values(by=['IN_FID', 'NEAR_DIST'])

# Add a new rank column based on sorted distances
sorted_df['Distance_Rank'] = sorted_df.groupby('IN_FID')['NEAR_DIST'].rank(method='first').astype(int)

# Pivot the table based on IN_FID and the new Distance_Rank, using NEAR_DIST as the values
piv_df = sorted_df.pivot_table(index='IN_FID', columns='Distance_Rank', values='Installed Capacity (MWelec)', aggfunc='first')

# Rename the columns to Dist1_Headspace, Dist2_Headspace, etc.
piv_df.columns = [f'Dist{int(col)}_Installed Capacity (MWelec)' for col in piv_df.columns]

# Reset the index to bring IN_FID back as a column
piv_df.reset_index(inplace=True)

# Merge the pivoted DataFrame back with the original DataFrame to retain other columns
final_df = pd.merge(merged_df.drop_duplicates(subset=['IN_FID']), piv_df, on='IN_FID', how='left')

# Display the final DataFrame
final_df
# Out:
#       OBJECTID                                         Site Name  \
# 0          346                                           Striven
# 1          348                                         Kilmorack
# 2          361                         Beeston Weir Hydro Scheme
# 3          361                         Beeston Weir Hydro Scheme
# 4          361                         Beeston Weir Hydro Scheme
# ...        ...                                               ...
# 1055      6663  Morrisons, Bradford Road, Idle - Solar PV Panels
# 1056      6663  Morrisons, Bradford Road, Idle - Solar PV Panels
# 1057      7139                     Dolphin Square - Solar panels
# 1058      7262          Blanche Lane, South Mimms - Solar Panels
# 1059      8217                          Nethermains - Solar Farm
#
#           Technology Type Installed Capacity (MWelec)  Development Status  \
# 0             Large Hydro                           8         Operational
# 1             Large Hydro                          20         Operational
# 2             Small Hydro                         1.7         Operational
# 3             Small Hydro                         1.7         Operational
# 4             Small Hydro                         1.7         Operational
# ...                   ...                         ...                 ...
# 1055  Solar Photovoltaics                         0.8         Operational
# 1056  Solar Photovoltaics                         0.8         Operational
# 1057  Solar Photovoltaics                      <Null>  Under Construction
# 1058  Solar Photovoltaics                        0.61  Under Construction
# 1059  Solar Photovoltaics                         7.5  Under Construction
#
#       IN_FID     NEAR_DIST  NEAR_RANK Dist1_Installed Capacity (MWelec)  \
# 0        430  15756.589891          3                              0.34
# 1        994   6962.379263          2                                18
# 2        305   3152.935140          2                              0.35
# 3        834   1748.284874          1                               1.7
# 4        842   3798.697145          3                              0.35
# ...      ...           ...        ...                               ...
# 1055     599   5771.357986          1                               0.8
# 1056     985   8299.490165          2                            <Null>
# 1057     555   5904.589571          1                            <Null>
# 1058     698   5699.916929          2                            <Null>
# 1059     542    410.621480          1                               7.5
#
#      Dist2_Installed Capacity (MWelec) Dist3_Installed Capacity (MWelec)
# 0                                  1.4                                 8
# 1                                   20                                15
# 2                                  1.7                              0.18
# 3                                 0.35                              0.36
# 4                                 0.18                               1.7
# ...                                ...                               ...
# 1055                            <Null>                              0.22
# 1056                               0.8                              0.31
# 1057                              0.43                              0.18
# 1058                              0.61                                 3
# 1059                                19                                 5
#
# [1060 rows x 11 columns]

# %%
# Drop the specified columns from the nt DataFrame
final_df = final_df.drop(columns=['Site Name', 'Technology Type', 'Development Status', 'NEAR_RANK', 'NEAR_DIST'])

final_df
# Out:
#       OBJECTID Installed Capacity (MWelec)  IN_FID  \
# 0          346                           8     430
# 1          348                          20     994
# 2          361                         1.7     305
# 3          361                         1.7     834
# 4          361                         1.7     842
# ...        ...                         ...     ...
# 1055      6663                         0.8     599
# 1056      6663                         0.8     985
# 1057      7139                      <Null>     555
# 1058      7262                        0.61     698
# 1059      8217                         7.5     542
#
#      Dist1_Installed Capacity (MWelec) Dist2_Installed Capacity (MWelec)  \
# 0                                 0.34                               1.4
# 1                                   18                                20
# 2                                 0.35                               1.7
# 3                                  1.7                              0.35
# 4                                 0.35                              0.18
# ...                                ...                               ...
# 1055                               0.8                            <Null>
# 1056                            <Null>                               0.8
# 1057                            <Null>                              0.43
# 1058                            <Null>                              0.61
# 1059                               7.5                                19
#
#      Dist3_Installed Capacity (MWelec)
# 0                                    8
# 1                                   15
# 2                                 0.18
# 3                                 0.36
# 4                                  1.7
# ...                                ...
# 1055                              0.22
# 1056                              0.31
# 1057                              0.18
# 1058                                 3
# 1059                                 5
#
# [1060 rows x 6 columns]

# %%
# To check data types of all columns in a DataFrame
print(final_df.dtypes)
# Out:
# OBJECTID                              int64
# Installed Capacity (MWelec)          object
# IN_FID                                int64
# Dist1_Installed Capacity (MWelec)    object
# Dist2_Installed Capacity (MWelec)    object
# Dist3_Installed Capacity (MWelec)    object
# dtype: object

# %%
# Convert a specific column from object to float
final_df['Dist1_Installed Capacity (MWelec)'] = pd.to_numeric(final_df['Dist1_Installed Capacity (MWelec)'], errors='coerce')
final_df['Dist2_Installed Capacity (MWelec)'] = pd.to_numeric(final_df['Dist2_Installed Capacity (MWelec)'], errors='coerce')
final_df['Dist3_Installed Capacity (MWelec)'] = pd.to_numeric(final_df['Dist3_Installed Capacity (MWelec)'], errors='coerce')

final_df
# Out:
#       OBJECTID Installed Capacity (MWelec)  IN_FID  \
# 0          346                           8     430
# 1          348                          20     994
# 2          361                         1.7     305
# 3          361                         1.7     834
# 4          361                         1.7     842
# ...        ...                         ...     ...
# 1055      6663                         0.8     599
# 1056      6663                         0.8     985
# 1057      7139                      <Null>     555
# 1058      7262                        0.61     698
# 1059      8217                         7.5     542
#
#       Dist1_Installed Capacity (MWelec)  Dist2_Installed Capacity (MWelec)  \
# 0                                  0.34                               1.40
# 1                                 18.00                              20.00
# 2                                  0.35                               1.70
# 3                                  1.70                               0.35
# 4                                  0.35                               0.18
# ...                                 ...                                ...
# 1055                               0.80                                NaN
# 1056                                NaN                               0.80
# 1057                                NaN                               0.43
# 1058                                NaN                               0.61
# 1059                               7.50                              19.00
#
#       Dist3_Installed Capacity (MWelec)
# 0                                  8.00
# 1                                 15.00
# 2                                  0.18
# 3                                  0.36
# 4                                  1.70
# ...                                 ...
# 1055                               0.22
# 1056                               0.31
# 1057                               0.18
# 1058                               3.00
# 1059                               5.00
#
# [1060 rows x 6 columns]

# %%
# Count the number of missing values in each column
final_df.isnull().sum()
# Out:
# OBJECTID                              0
# Installed Capacity (MWelec)           0
# IN_FID                                0
# Dist1_Installed Capacity (MWelec)    64
# Dist2_Installed Capacity (MWelec)    34
# Dist3_Installed Capacity (MWelec)    37
# dtype: int64

# %%
# Fill the null PF values with the average of existing numeric PF values
final_df['Dist1_Installed Capacity (MWelec)'].fillna(final_df['Dist1_Installed Capacity (MWelec)'].mean(), inplace=True)
final_df['Dist2_Installed Capacity (MWelec)'].fillna(final_df['Dist2_Installed Capacity (MWelec)'].mean(), inplace=True)
final_df['Dist3_Installed Capacity (MWelec)'].fillna(final_df['Dist3_Installed Capacity (MWelec)'].mean(), inplace=True)

final_df
# Out:
#       OBJECTID Installed Capacity (MWelec)  IN_FID  \
# 0          346                           8     430
# 1          348                          20     994
# 2          361                         1.7     305
# 3          361                         1.7     834
# 4          361                         1.7     842
# ...        ...                         ...     ...
# 1055      6663                         0.8     599
# 1056      6663                         0.8     985
# 1057      7139                      <Null>     555
# 1058      7262                        0.61     698
# 1059      8217                         7.5     542
#
#       Dist1_Installed Capacity (MWelec)  Dist2_Installed Capacity (MWelec)  \
# 0                              0.340000                           1.400000
# 1                             18.000000                          20.000000
# 2                              0.350000                           1.700000
# 3                              1.700000                           0.350000
# 4                              0.350000                           0.180000
# ...                                 ...                                ...
# 1055                           0.800000                           6.737622
# 1056                           6.586386                           0.800000
# 1057                           6.586386                           0.430000
# 1058                           6.586386                           0.610000
# 1059                           7.500000                          19.000000
#
#       Dist3_Installed Capacity (MWelec)
# 0                                  8.00
# 1                                 15.00
# 2                                  0.18
# 3                                  0.36
# 4                                  1.70
# ...                                 ...
# 1055                               0.22
# 1056                               0.31
# 1057                               0.18
# 1058                               3.00
# 1059                               5.00
#
# [1060 rows x 6 columns]

# %%
# Creating the new column 'Mean_Headspace(MVA)' by averaging the three headspace columns
final_df['Mean_Installed_Capacity(MWelec)'] = (final_df['Dist1_Installed Capacity (MWelec)'] + final_df['Dist2_Installed Capacity (MWelec)'] + final_df['Dist3_Installed Capacity (MWelec)']) / 3

final_df
# Out:
#       OBJECTID Installed Capacity (MWelec)  IN_FID  \
# 0          346                           8     430
# 1          348                          20     994
# 2          361                         1.7     305
# 3          361                         1.7     834
# 4          361                         1.7     842
# ...        ...                         ...     ...
# 1055      6663                         0.8     599
# 1056      6663                         0.8     985
# 1057      7139                      <Null>     555
# 1058      7262                        0.61     698
# 1059      8217                         7.5     542
#
#       Dist1_Installed Capacity (MWelec)  Dist2_Installed Capacity (MWelec)  \
# 0                              0.340000                           1.400000
# 1                             18.000000                          20.000000
# 2                              0.350000                           1.700000
# 3                              1.700000                           0.350000
# 4                              0.350000                           0.180000
# ...                                 ...                                ...
# 1055                           0.800000                           6.737622
# 1056                           6.586386                           0.800000
# 1057                           6.586386                           0.430000
# 1058                           6.586386                           0.610000
# 1059                           7.500000                          19.000000
#
#       Dist3_Installed Capacity (MWelec)  Mean_Installed_Capacity(MWelec)
# 0                                  8.00                         3.246667
# 1                                 15.00                        17.666667
# 2                                  0.18                         0.743333
# 3                                  0.36                         0.803333
# 4                                  1.70                         0.743333
# ...                                 ...                              ...
# 1055                               0.22                         2.585874
# 1056                               0.31                         2.565462
# 1057                               0.18                         2.398795
# 1058                               3.00                         3.398795
# 1059                               5.00                        10.500000
#
# [1060 rows x 7 columns]

# %%
# the number of hours in a year
hours_in_year = 8760

# Calculate Mean Installed Capacity in MWh
final_df['Mean_Installed_Capacity(MWH)'] = final_df['Mean_Installed_Capacity(MWelec)'] * hours_in_year

final_df
# Out:
#       OBJECTID Installed Capacity (MWelec)  IN_FID  \
# 0          346                           8     430
# 1          348                          20     994
# 2          361                         1.7     305
# 3          361                         1.7     834
# 4          361                         1.7     842
# ...        ...                         ...     ...
# 1055      6663                         0.8     599
# 1056      6663                         0.8     985
# 1057      7139                      <Null>     555
# 1058      7262                        0.61     698
# 1059      8217                         7.5     542
#
#       Dist1_Installed Capacity (MWelec)  Dist2_Installed Capacity (MWelec)  \
# 0                              0.340000                           1.400000
# 1                             18.000000                          20.000000
# 2                              0.350000                           1.700000
# 3                              1.700000                           0.350000
# 4                              0.350000                           0.180000
# ...                                 ...                                ...
# 1055                           0.800000                           6.737622
# 1056                           6.586386                           0.800000
# 1057                           6.586386                           0.430000
# 1058                           6.586386                           0.610000
# 1059                           7.500000                          19.000000
#
#       Dist3_Installed Capacity (MWelec)  Mean_Installed_Capacity(MWelec)  \
# 0                                  8.00                         3.246667
# 1                                 15.00                        17.666667
# 2                                  0.18                         0.743333
# 3                                  0.36                         0.803333
# 4                                  1.70                         0.743333
# ...                                 ...                              ...
# 1055                               0.22                         2.585874
# 1056                               0.31                         2.565462
# 1057                               0.18                         2.398795
# 1058                               3.00                         3.398795
# 1059                               5.00                        10.500000
#
#       Mean_Installed_Capacity(MWH)
# 0                     28440.800000
# 1                    154760.000000
# 2                      6511.600000
# 3                      7037.200000
# 4                      6511.600000
# ...                            ...
# 1055                  22652.255750
# 1056                  22473.445783
# 1057                  21013.445783
# 1058                  29773.445783
# 1059                  91980.000000
#
# [1060 rows x 8 columns]

# %%
# Check for null values in the dataframe
null_values = final_df.isnull().sum()

null_values
# Out:
# OBJECTID                             0
# Installed Capacity (MWelec)          0
# IN_FID                               0
# Dist1_Installed Capacity (MWelec)    0
# Dist2_Installed Capacity (MWelec)    0
# Dist3_Installed Capacity (MWelec)    0
# Mean_Installed_Capacity(MWelec)      0
# Mean_Installed_Capacity(MWH)         0
# dtype: int64

# %%
# Export the final DataFrame to a CSV file
final_df.to_csv('C:/Users/USER/Desktop/MSc_Data_Science/Ind_Project/GHD/Project/Data/RE_mean_capacity.csv', index=False)

# Confirm that the file was saved successfully
print("Data exported successfully!")
# Out:
# Data exported successfully!
